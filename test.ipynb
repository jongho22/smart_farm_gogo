# %%
from datetime import datetime,date

now = datetime.now()
time = now.strftime('%Y-%m-%d %H:%M:%S')
data_rev_time = now.strptime(time,'%Y-%m-%d %H:%M:%S')

#print(time)
print(data_rev_time)
# Out:
# 2022-11-23 21:45:58
